# %% [markdown]
# <a href="https://colab.research.google.com/github/amscally-dsci/dd-test-public/blob/main/Suggestions_on_EDA_process.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('Housing.Data.csv')

# Display the first few rows
print("First 5 rows of the dataset:")
print(df.head())

# Display general information about the DataFrame
print("\nGeneral information about the dataset:")
print(df.info())

# %% [markdown]
# ```text?code_stdout&code_event_index=2
# First 5 rows of the dataset:
#          PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating Heating QC Central Air Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  Fireplaces Fireplace Qu Garage Type  Garage Yr Blt Garage Finish  Garage Cars  Garage Area Garage Qual Garage Cond Paved Drive  Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area Pool QC  Fence Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type Sale Condition  SalePrice
# 0  905101070           20        RL          62.0     14299   Pave   NaN       Reg          Lvl    AllPub     Inside        Gtl       Sawyer       Feedr        Norm      1Fam      1Story             4             3        1964            1964      Gable   CompShg      HdBoard      HdBoard         None           0.0         TA         TA     CBlock        TA        TA            No            Rec         513.0            LwQ         144.0        348.0         1005.0    GasA         TA           Y      SBrkr        1005           0                0         1005             1.0             0.0          1          0              3              1           TA              5        Typ           0          NaN      Detchd         1964.0           Unf          2.0        440.0          TA          TA           N             0              0               0           0             0          0     NaN  MnPrv          NaN         0        7     2007       WD          Normal     115400
# 1  905101330           90        RL          72.0     10791   Pave   NaN       Reg          Lvl    AllPub     Inside        Gtl       Sawyer        Norm        Norm    Duplex      1Story             4             5        1967            1967      Gable   CompShg      MetalSd      MetalSd         None           0.0         TA         TA       Slab       NaN       NaN           NaN            NaN           0.0            NaN           0.0          0.0            0.0    GasA         TA           Y      SBrkr        1296           0                0         1296             0.0             0.0          2          0              2              2           TA              6        Typ           0          NaN     CarPort         1967.0           Unf          2.0        516.0          TA          TA           Y             0              0               0           0             0          0     NaN    NaN         Shed       500       10     2006       WD          Normal      90000
# 2  903454090           50        RM          50.0      9000   Pave   NaN       Reg          Bnk    AllPub     Inside        Gtl       IDOTRR        Norm        Norm      1Fam      1.5Fin             6             6        1937            1950      Gable   CompShg      Wd Sdng      Wd Sdng         None           0.0         TA         Gd      PConc        TA        TA            No            Unf           0.0            Unf           0.0        780.0          780.0    GasA         TA           Y      SBrkr         780         595                0         1375             0.0             0.0          1          1              3              1           Gd              6        Typ           1           Gd      Detchd         1979.0           Unf          1.0        544.0          TA          TA           P             0            162               0           0           126          0     NaN    NaN          NaN         0       12     2007       WD          Normal     141000
# 3  533244030           60        FV          68.0      7379   Pave   NaN       IR1          Lvl    AllPub     Inside        Gtl      Somerst        Norm        Norm      1Fam      2Story             8             5        2000            2000      Gable   CompShg      VinylSd      VinylSd         None           0.0         Gd         TA      PConc        Gd        TA            No            GLQ         484.0            Unf           0.0        491.0          975.0    GasA         Ex           Y      SBrkr         975         873                0         1848             1.0             0.0          2          1              3              1           Gd              7        Typ           1           TA      Attchd         2000.0           RFn          2.0        592.0          TA          TA           Y           280            184               0           0             0          0     NaN    NaN          NaN         0        4     2010       WD          Normal     254000
# 4  909252020           70        RL          60.0      7200   Pave   NaN       Reg          Lvl    AllPub     Inside        Gtl        SWISU       Feedr        Norm      1Fam      2Story             7             9        1936            2007      Gable   CompShg      Wd Sdng      Wd Sdng         None           0.0         Gd         Gd      PConc        Gd        Gd            No            ALQ         350.0            BLQ         210.0          0.0          560.0    GasA         Ex           Y      SBrkr         575         560                0         1135             1.0             0.0          1          0              3              1           Gd              6        Typ           0          NaN      Detchd         1971.0           RFn          2.0        576.0          TA          TA           Y           256              0               0           0             0          0     NaN  MnPrv          NaN         0        4     2009       WD          Normal     155000
#
# General information about the dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2637 entries, 0 to 2636
# Data columns (total 81 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PID              2637 non-null   int64
#  1   MS SubClass      2637 non-null   int64
#  2   MS Zoning        2637 non-null   object
#  3   Lot Frontage     2188 non-null   float64
#  4   Lot Area         2637 non-null   int64
#  5   Street           2637 non-null   object
#  6   Alley            180 non-null    object
#  7   Lot Shape        2637 non-null   object
#  8   Land Contour     2637 non-null   object
#  9   Utilities        2637 non-null   object
#  10  Lot Config       2637 non-null   object
#  11  Land Slope       2637 non-null   object
#  12  Neighborhood     2637 non-null   object
#  13  Condition 1      2637 non-null   object
#  14  Condition 2      2637 non-null   object
#  15  Bldg Type        2637 non-null   object
#  16  House Style      2637 non-null   object
#  17  Overall Qual     2637 non-null   int64
#  18  Overall Cond     2637 non-null   int64
#  19  Year Built       2637 non-null   int64
#  20  Year Remod/Add   2637 non-null   int64
#  21  Roof Style       2637 non-null   object
#  22  Roof Matl        2637 non-null   object
#  23  Exterior 1st     2637 non-null   object
#  24  Exterior 2nd     2637 non-null   object
#  25  Mas Vnr Type     2614 non-null   object
#  26  Mas Vnr Area     2614 non-null   float64
#  27  Exter Qual       2637 non-null   object
#  28  Exter Cond       2637 non-null   object
#  29  Foundation       2637 non-null   object
#  30  Bsmt Qual        2564 non-null   object
#  31  Bsmt Cond        2564 non-null   object
#  32  Bsmt Exposure    2561 non-null   object
#  33  BsmtFin Type 1   2564 non-null   object
#  34  BsmtFin SF 1     2636 non-null   float64
#  35  BsmtFin Type 2   2563 non-null   object
#  36  BsmtFin SF 2     2636 non-null   float64
#  37  Bsmt Unf SF      2636 non-null   float64
#  38  Total Bsmt SF    2636 non-null   float64
#  39  Heating          2637 non-null   object
#  40  Heating QC       2637 non-null   object
#  41  Central Air      2637 non-null   object
#  42  Electrical       2637 non-null   object
#  43  1st Flr SF       2637 non-null   int64
#  44  2nd Flr SF       2637 non-null   int64
#  45  Low Qual Fin SF  2637 non-null   int64
#  46  Gr Liv Area      2637 non-null   int64
#  47  Bsmt Full Bath   2635 non-null   float64
#  48  Bsmt Half Bath   2635 non-null   float64
#  49  Full Bath        2637 non-null   int64
#  50  Half Bath        2637 non-null   int64
#  51  Bedroom AbvGr    2637 non-null   int64
#  52  Kitchen AbvGr    2637 non-null   int64
#  53  Kitchen Qual     2637 non-null   object
#  54  TotRms AbvGrd    2637 non-null   int64
#  55  Functional       2637 non-null   object
#  56  Fireplaces       2637 non-null   int64
#  57  Fireplace Qu     1353 non-null   object
#  58  Garage Type      2492 non-null   object
#  59  Garage Yr Blt    2490 non-null   float64
#  60  Garage Finish    2490 non-null   object
#  61  Garage Cars      2636 non-null   float64
#  62  Garage Area      2636 non-null   float64
#  63  Garage Qual      2490 non-null   object
#  64  Garage Cond      2490 non-null   object
#  65  Paved Drive      2637 non-null   object
#  66  Wood Deck SF     2637 non-null   int64
#  67  Open Porch SF    2637 non-null   int64
#  68  Enclosed Porch   2637 non-null   int64
#  69  3Ssn Porch       2637 non-null   int64
#  70  Screen Porch     2637 non-null   int64
#  71  Pool Area        2637 non-null   int64
#  72  Pool QC          11 non-null     object
#  73  Fence            528 non-null    object
#  74  Misc Feature     96 non-null     object
#  75  Misc Val         2637 non-null   int64
#  76  Mo Sold          2637 non-null   int64
#  77  Yr Sold          2637 non-null   int64
#  78  Sale Type        2637 non-null   object
#  79  Sale Condition   2637 non-null   object
#  80  SalePrice        2637 non-null   int64
# dtypes: float64(11), int64(27), object(43)
# memory usage: 1.6+ MB
# None
#
# ```

# %%
# Identify object columns
object_cols = df.select_dtypes(include='object').columns

print("\n--- Exploratory Data Analysis for Object Columns ---\n")

for col in object_cols:
    print(f"Column: '{col}'")
    print(f"Number of unique values: {df[col].nunique()}")
    print("Value Counts:")
    print(df[col].value_counts(dropna=False)) # Include NaN counts
    print(f"Missing Values: {df[col].isnull().sum()} out of {len(df[col])} ({df[col].isnull().sum()/len(df[col])*100:.2f}%)\n")
    print("-" * 50)

# %% [markdown]
# ```text?code_stdout&code_event_index=6
#
# --- Exploratory Data Analysis for Object Columns ---
#
# Column: 'MS Zoning'
# Number of unique values: 7
# Value Counts:
# RL         2043
# RM          419
# FV          123
# C (all)      25
# RH           23
# I (all)       2
# A (agr)       2
# Name: MS Zoning, dtype: int64
# Missing Values: 0 out of 2637 (0.00%)
#
# --------------------------------------------------
# Column: 'Street'
# Number of unique values: 2
# Value Counts:
# Pave    2625
# Grvl      12
# Name: Street, dtype: int64
# Missing Values: 0 out of 2637 (0.00%)
#
# --------------------------------------------------
# Column: 'Alley'
# Number of unique values: 2
# Value Counts:
# NaN     2457
# Grvl     111
# Pave      69
# Name: Alley, dtype: int64
# Missing Values: 2457 out of 2637 (93.17%)
#
# --------------------------------------------------
# Column: 'Lot Shape'
# Number of unique values: 4
# Value Counts:
# Reg    1662
# IR1     895
# IR2      65
# IR3      15
# Name: Lot Shape, dtype: int64
# Missing Values: 0 out of 2637 (0.00%)
#
# --------------------------------------------------
# Column: 'Land Contour'
# Number of unique values: 4
# Value Counts:
# Lvl    2365
# HLS     111
# Bnk     106
# Low      55
# Name: Land Contour, dtype: int64
# Missing Values: 0 out of 2637 (0.00%)
#
# --------------------------------------------------
# Column: 'Utilities'
# Number of unique values: 3
# Value Counts:
# AllPub    2634
# NoSewr       2
# NoSeWa       1
# Name: Utilities, dtype: int64
# Missing Values: 0 out of 2637 (0.00%)
#
# --------------------------------------------------
# Column: 'Lot Config'
# Number of unique values: 5
# Value Counts:
# Inside     1924
# Corner      459
# CulDSac     160
# FR2          81
# FR3          13
# Name: Lot Config, dtype: int64
# Missing Values: 0 out of 2637 (0.00%)
#
# --------------------------------------------------
# Column: 'Land Slope'
# Number of unique values: 3
# Value Counts:
# Gtl    2511
# Mod     112
# Sev      14
# Name: Land Slope, dtype: int64
# Missing Values: 0 out of 2637 (0.00%)
#
# --------------------------------------------------
# Column: 'Neighborhood'
# Number of unique values: 28
# Value Counts:
# NAmes      397
# CollgCr    240
# OldTown    218
# Edwards    168
# Somerst    161
# NridgHt    150
# Gilbert    149
# Sawyer     138
# NWAmes     116
# SawyerW    110
# Mitchel    105
# BrkSide     97
# Crawfor     95
# IDOTRR      84
# NoRidge     65
# Timber      62
# StoneBr     49
# SWISU       44
# ClearCr     39
# MeadowV     34
# BrDale      28
# Veenker     24
# Blmngtn     23
# NPkVill     20
# Blueste     10
# Greens       8
# GrnHill      2
# Landmrk      1
# Name: Neighborhood, dtype: int64
# Missing Values: 0 out of 2637 (0.00%)
#
# --------------------------------------------------
# Column: 'Condition 1'
# Number of unique values: 9
# Value Counts:
# Norm      2273
# Feedr      148
# Artery      83
# RRAn        42
# PosN        32
# RRAe        27
# PosA        19
# RRNn         8
# RRNe         5
# Name: Condition 1, dtype: int64
# Missing Values: 0 out of 2637 (0.00%)
#
# --------------------------------------------------
# Column: 'Condition 2'
# Number of unique values: 8
# Value Counts:
# Norm      2609
# Feedr       11
# Artery       5
# PosA         4
# PosN         4
# RRNn         2
# RRAe         1
# RRAn         1
# Name: Condition 2, dtype: int64
# Missing Values: 0 out of 2637 (0.00%)
#
# --------------------------------------------------
# Column: 'Bldg Type'
# Number of unique values: 5
# Value Counts:
# 1Fam      2187
# TwnhsE     210
# Duplex      95
# Twnhs       90
# 2fmCon      55
# Name: Bldg Type, dtype: int64
# Missing Values: 0 out of 2637 (0.00%)
#
# --------------------------------------------------
# Column: 'House Style'
# Number of unique values: 8
# Value Counts:
# 1Story    1327
# 2Story     800
# 1.5Fin     276
# SLvl       113
# SFoyer      76
# 2.5Unf      21
# 1.5Unf      17
# 2.5Fin       7
# Name: House Style, dtype: int64
# Missing Values: 0 out of 2637 (0.00%)
#
# --------------------------------------------------
# Column: 'Roof Style'
# Number of unique values: 6
# Value Counts:
# Gable      2086
# Hip         498
# Gambrel      21
# Flat         18
# Mansard       9
# Shed          5
# Name: Roof Style, dtype: int64
# Missing Values: 0 out of 2637 (0.00%)
#
# --------------------------------------------------
# Column: 'Roof Matl'
# Number of unique values: 8
# Value Counts:
# CompShg    2599
# Tar&Grv      20
# WdShake       8
# WdShngl       6
# Roll          1
# Membran       1
# Metal         1
# ClyTile       1
# Name: Roof Matl, dtype: int64
# Missing Values: 0 out of 2637 (0.00%)
#
# --------------------------------------------------
# Column: 'Exterior 1st'
# Number of unique values: 16
# Value Counts:
# VinylSd    916
# MetalSd    411
# HdBoard    403
# Wd Sdng    380
# Plywood    195
# CemntBd    114
# BrkFace     77
# WdShing     50
# AsbShng     44
# Stucco      36
# BrkComm      3
# CBlock       2
# Stone        2
# AsphShn      2
# PreCast      1
# ImStucc      1
# Name: Exterior 1st, dtype: int64
# Missing Values: 0 out of 2637 (0.00%)
#
# --------------------------------------------------
# Column: 'Exterior 2nd'
# Number of unique values: 17
# Value Counts:
# VinylSd    906
# MetalSd    408
# HdBoard    368
# Wd Sdng    353
# Plywood    244
# CmentBd    114
# Wd Shng     76
# BrkFace     42
# Stucco      40
# AsbShng     38
# Brk Cmn     19
# ImStucc     15
# Stone        6
# AsphShn      3
# CBlock       3
# PreCast      1
# Other        1
# Name: Exterior 2nd, dtype: int64
# Missing Values: 0 out of 2637 (0.00%)
#
# --------------------------------------------------
# Column: 'Mas Vnr Type'
# Number of unique values: 5
# Value Counts:
# None       1584
# BrkFace     782
# Stone       224
# NaN          23
# BrkCmn       23
# CBlock        1
# Name: Mas Vnr Type, dtype: int64
# Missing Values: 23 out of 2637 (0.87%)
#
# --------------------------------------------------
# Column: 'Exter Qual'
# Number of unique values: 4
# Value Counts:
# TA    1614
# Gd     894
# Ex      96
# Fa      33
# Name: Exter Qual, dtype: int64
# Missing Values: 0 out of 2637 (0.00%)
#
# --------------------------------------------------
# Column: 'Exter Cond'
# Number of unique values: 5
# Value Counts:
# TA    2290
# Gd     273
# Fa      62
# Ex       9
# Po       3
# Name: Exter Cond, dtype: int64
# Missing Values: 0 out of 2637 (0.00%)
#
# --------------------------------------------------
# Column: 'Foundation'
# Number of unique values: 6
# Value Counts:
# PConc     1185
# CBlock    1116
# BrkTil     278
# Slab        44
# Stone       11
# Wood         3
# Name: Foundation, dtype: int64
# Missing Values: 0 out of 2637 (0.00%)
#
# --------------------------------------------------
# Column: 'Bsmt Qual'
# Number of unique values: 5
# Value Counts:
# TA     1161
# Gd     1093
# Ex      229
# Fa       79
# NaN      73
# Po        2
# Name: Bsmt Qual, dtype: int64
# Missing Values: 73 out of 2637 (2.77%)
#
# --------------------------------------------------
# Column: 'Bsmt Cond'
# Number of unique values: 5
# Value Counts:
# TA     2358
# Gd      107
# Fa       92
# NaN      73
# Po        5
# Ex        2
# Name: Bsmt Cond, dtype: int64
# Missing Values: 73 out of 2637 (2.77%)
#
# --------------------------------------------------
# Column: 'Bsmt Exposure'
# Number of unique values: 4
# Value Counts:
# No     1722
# Av      375
# Gd      248
# Mn      216
# NaN      76
# Name: Bsmt Exposure, dtype: int64
# Missing Values: 76 out of 2637 (2.88%)
#
# --------------------------------------------------
# Column: 'BsmtFin Type 1'
# Number of unique values: 6
# Value Counts:
# Unf    768
# GLQ    758
# ALQ    397
# Rec    262
# BLQ    237
# LwQ    142
# NaN     73
# Name: BsmtFin Type 1, dtype: int64
# Missing Values: 73 out of 2637 (2.77%)
#
# --------------------------------------------------
# Column: 'BsmtFin Type 2'
# Number of unique values: 6
# Value Counts:
# Unf    2245
# Rec     100
# LwQ      76
# NaN      74
# BLQ      60
# ALQ      50
# GLQ      32
# Name: BsmtFin Type 2, dtype: int64
# Missing Values: 74 out of 2637 (2.81%)
#
# --------------------------------------------------
# Column: 'Heating'
# Number of unique values: 6
# Value Counts:
# GasA     2597
# GasW       23
# Grav        9
# Wall        5
# OthW        2
# Floor       1
# Name: Heating, dtype: int64
# Missing Values: 0 out of 2637 (0.00%)
#
# --------------------------------------------------
# Column: 'Heating QC'
# Number of unique values: 5
# Value Counts:
# Ex    1355
# TA     778
# Gd     419
# Fa      82
# Po       3
# Name: Heating QC, dtype: int64
# Missing Values: 0 out of 2637 (0.00%)
#
# --------------------------------------------------
# Column: 'Central Air'
# Number of unique values: 2
# Value Counts:
# Y    2460
# N     177
# Name: Central Air, dtype: int64
# Missing Values: 0 out of 2637 (0.00%)
#
# --------------------------------------------------
# Column: 'Electrical'
# Number of unique values: 5
# Value Counts:
# SBrkr    2414
# FuseA     172
# FuseF      42
# FuseP       8
# Mix         1
# Name: Electrical, dtype: int64
# Missing Values: 0 out of 2637 (0.00%)
#
# --------------------------------------------------
# Column: 'Kitchen Qual'
# Number of unique values: 4
# Value Counts:
# TA    1342
# Gd    1052
# Ex     184
# Fa      59
# Name: Kitchen Qual, dtype: int64
# Missing Values: 0 out of 2637 (0.00%)
#
# --------------------------------------------------
# Column: 'Functional'
# Number of unique values: 8
# Value Counts:
# Typ     2453
# Min2      63
# Min1      58
# Mod       32
# Maj1      18
# Maj2       9
# Sal        2
# Sev        2
# Name: Functional, dtype: int64
# Missing Values: 0 out of 2637 (0.00%)
#
# --------------------------------------------------
# Column: 'Fireplace Qu'
# Number of unique values: 5
# Value Counts:
# NaN    1284
# Gd      675
# TA      538
# Fa       64
# Po       45
# Ex       31
# Name: Fireplace Qu, dtype: int64
# Missing Values: 1284 out of 2637 (48.69%)
#
# --------------------------------------------------
# Column: 'Garage Type'
# Number of unique values: 6
# Value Counts:
# Attchd     1563
# Detchd      702
# BuiltIn     165
# NaN         145
# Basment      28
# 2Types       20
# CarPort      14
# Name: Garage Type, dtype: int64
# Missing Values: 145 out of 2637 (5.50%)
#
# --------------------------------------------------
# Column: 'Garage Finish'
# Number of unique values: 3
# Value Counts:
# Unf    1106
# RFn     730
# Fin     654
# NaN     147
# Name: Garage Finish, dtype: int64
# Missing Values: 147 out of 2637 (5.57%)
#
# --------------------------------------------------
# Column: 'Garage Qual'
# Number of unique values: 5
# Value Counts:
# TA     2356
# NaN     147
# Fa      106
# Gd       20
# Po        5
# Ex        3
# Name: Garage Qual, dtype: int64
# Missing Values: 147 out of 2637 (5.57%)
#
# --------------------------------------------------
# Column: 'Garage Cond'
# Number of unique values: 5
# Value Counts:
# TA     2400
# NaN     147
# Fa       60
# Po       14
# Gd       14
# Ex        2
# Name: Garage Cond, dtype: int64
# Missing Values: 147 out of 2637 (5.57%)
#
# --------------------------------------------------
# Column: 'Paved Drive'
# Number of unique values: 3
# Value Counts:
# Y    2395
# N     187
# P      55
# Name: Paved Drive, dtype: int64
# Missing Values: 0 out of 2637 (0.00%)
#
# --------------------------------------------------
# Column: 'Pool QC'
# Number of unique values: 4
# Value Counts:
# NaN    2626
# Gd        4
# Ex        3
# Fa        2
# TA        2
# Name: Pool QC, dtype: int64
# Missing Values: 2626 out of 2637 (99.58%)
#
# --------------------------------------------------
# Column: 'Fence'
# Number of unique values: 4
# Value Counts:
# NaN      2109
# MnPrv     306
# GdPrv     108
# GdWo      103
# MnWw       11
# Name: Fence, dtype: int64
# Missing Values: 2109 out of 2637 (79.98%)
#
# --------------------------------------------------
# Column: 'Misc Feature'
# Number of unique values: 4
# Value Counts:
# NaN     2541
# Shed      87
# Gar2       4
# Othr       4
# TenC       1
# Name: Misc Feature, dtype: int64
# Missing Values: 2541 out of 2637 (96.36%)
#
# --------------------------------------------------
# Column: 'Sale Type'
# Number of unique values: 10
# Value Counts:
# WD       2286
# New       216
# COD        78
# ConLD      21
# CWD        11
# ConLI       7
# Oth         6
# ConLw       6
# Con         5
# VWD         1
# Name: Sale Type, dtype: int64
# Missing Values: 0 out of 2637 (0.00%)
#
# --------------------------------------------------
# Column: 'Sale Condition'
# Number of unique values: 6
# Value Counts:
# Normal     2166
# Partial     222
# Abnorml     174
# Family       44
# Alloca       21
# AdjLand      10
# Name: Sale Condition, dtype: int64
# Missing Values: 0 out of 2637 (0.00%)
#
# --------------------------------------------------
#
# ```
# Exploratory Data Analysis (EDA) on the 'object' columns of your `Housing.Data.csv` dataset has revealed important characteristics. Here's a summary of the findings and suggestions for further analysis and data preparation:
#
# The dataset contains 43 'object' type columns, many of which are nominal or ordinal as described in your documentation.
#
# **Key Observations and Suggestions for EDA on 'Object' Columns:**
#
# 1.  **High Cardinality vs. Low Cardinality:**
#     * [cite_start]**Low Cardinality (Few Unique Values):** Many columns, such as `Street` [cite: 64][cite_start], `Alley` [cite: 64][cite_start], `Lot Shape` [cite: 64][cite_start], `Land Contour` [cite: 64][cite_start], `Utilities` [cite: 64][cite_start], `Lot Config` [cite: 64][cite_start], `Land Slope` [cite: 64][cite_start], `Central Air` [cite: 78][cite_start], and `Paved Drive`[cite: 84], have a small number of unique values. These are excellent candidates for direct one-hot encoding if you plan to use them in machine learning models, or for simple frequency distribution visualizations (bar charts).
#     * [cite_start]**High Cardinality (Many Unique Values):** `Neighborhood` [cite: 65] [cite_start](28 unique values) and `Exterior 2nd` [cite: 70] (17 unique values) have a higher number of unique values. For `Neighborhood`, you might explore if some neighborhoods can be grouped based on average sale price or other characteristics to reduce dimensionality if needed for modeling.
#
# 2.  **Missing Values (`NaN`):**
#     A significant number of 'object' columns have missing values, which need to be addressed before most analytical or machine learning tasks.
#     * **Very High Missingness:**
#         * [cite_start]`Pool QC`[cite: 85]: 99.58% missing. Given this, it's highly likely that most houses do not have a pool, and the `NaN` correctly indicates 'No Pool'. This column might be dropped or converted to a binary 'Has Pool' column.
#         * [cite_start]`Misc Feature`[cite: 85]: 96.36% missing. Similar to `Pool QC`, 'NA' indicates 'None'. This might be an indicator of the absence of a miscellaneous feature.
#         * [cite_start]`Alley`[cite: 64]: 93.17% missing. [cite_start]The documentation states 'NA' means 'No alley access'[cite: 64]. This should be treated as a valid category.
#         * [cite_start]`Fence`[cite: 85]: 79.98% missing. [cite_start]'NA' means 'No Fence'[cite: 85]. This is another instance where missing values represent a meaningful category.
#         * [cite_start]`Fireplace Qu`[cite: 83]: 48.69% missing. [cite_start]'NA' means 'No Fireplace'[cite: 83]. This can be treated as a separate category.
#
#     * **Moderate Missingness (related to basement and garage features):**
#         * [cite_start]`Bsmt Qual`[cite: 71]: 2.77% missing. [cite_start]'NA' means 'No Basement'[cite: 71].
#         * [cite_start]`Bsmt Cond`[cite: 71]: 2.77% missing. [cite_start]'NA' means 'No Basement'[cite: 71].
#         * [cite_start]`Bsmt Exposure`[cite: 71]: 2.88% missing. [cite_start]'NA' means 'No Basement'[cite: 71].
#         * [cite_start]`BsmtFin Type 1`[cite: 71]: 2.77% missing. [cite_start]'NA' means 'No Basement'[cite: 71].
#         * [cite_start]`BsmtFin Type 2`[cite: 72]: 2.81% missing. [cite_start]'NA' means 'No Basement'[cite: 73].
#         * [cite_start]`Garage Type`[cite: 84]: 5.50% missing. [cite_start]'NA' means 'No Garage'[cite: 84].
#         * [cite_start]`Garage Finish`[cite: 84]: 5.57% missing. [cite_start]'NA' means 'No Garage'[cite: 84].
#         * [cite_start]`Garage Qual`[cite: 84]: 5.57% missing. [cite_start]'NA' means 'No Garage'[cite: 84].
#         * [cite_start]`Garage Cond`[cite: 84]: 5.57% missing. [cite_start]'NA' means 'No Garage'[cite: 84].
#
#         For these basement and garage related columns, the missing values generally indicate the absence of that feature. It's crucial to replace `NaN` with a specific category like 'No Basement' or 'No Garage' (as suggested by the documentation) rather than dropping them, as this 'missingness' itself is informative.
#
#     * **Low Missingness:**
#         * [cite_start]`Mas Vnr Type`[cite: 69]: 0.87% missing. [cite_start]The documentation indicates 'None' is a category[cite: 69], so these `NaN`s might correspond to 'None' or truly missing data that needs to be imputed or investigated.
#
# 3.  **Inconsistent Labeling/Categorization:**
#     * [cite_start]Some value counts show categories like 'C (all)' [cite: 63] [cite_start]and 'A (agr)' [cite: 63] [cite_start]in `MS Zoning`, and 'Brk Cmn' [cite: 70] in `Exterior 2nd`. While the data dictionary explains these, if the original data had variations (e.g., 'C' vs 'C (all)'), it's important to standardize them for consistency.
#     * Check for typographical errors or multiple ways of expressing the same category (e.g., 'Wd Sdng' vs 'Wd Sdng' with trailing space).
#
# **Suggestions for Next Steps in EDA:**
#
# 1.  **Data Cleaning/Preprocessing for Missing Values:**
#     * For columns where `NaN` explicitly means "None" or "No X" (e.g., `Alley`, `Pool QC`, `Fence`, `Fireplace Qu`, all `Bsmt` and `Garage` related quality/condition/type columns), fill `NaN` values with a descriptive string like 'NoAlleyAccess', 'NoPool', 'NoFence', 'NoFireplace', 'NoBasement', 'NoGarage' respectively, to turn them into proper categories. This retains valuable information.
#     * For `Mas Vnr Type`, investigate if `NaN` should be 'None' or if imputation is necessary.
#
# 2.  **Visualizations:**
#     * Create **bar plots** for all 'object' columns to visually inspect the distribution of categories. This helps to quickly grasp the most frequent and rare categories.
#     * [cite_start]For ordinal variables (e.g., `Overall Qual` [cite: 67][cite_start], `Exter Qual` [cite: 70][cite_start], `Bsmt Qual` [cite: 71][cite_start], `Kitchen Qual` [cite: 81]), ensure that plots respect the inherent order of categories if you are presenting them.
#
# 3.  **Relationship with Target Variable (`SalePrice`):**
#     * Group the data by each 'object' column and calculate the *median* or *mean* `SalePrice` for each category. This can reveal which categories within an object variable tend to have higher or lower sale prices. [cite_start]For example, which `Neighborhood` [cite: 65] generally has higher home values? [cite_start]Which `House Style` [cite: 67] is more expensive?
#     * Use box plots or violin plots to visualize the distribution of `SalePrice` across different categories of important 'object' variables.
#
# 4.  **Feature Engineering (if applicable):**
#     * Based on your domain knowledge and the EDA, consider creating new features from existing 'object' columns. For instance, you could create a binary feature 'HasAlley' from the `Alley` column.
#
# By systematically going through these steps, you will gain a deeper understanding of your categorical data, identify potential issues, and prepare your dataset for more advanced analysis or machine learning modeling.
